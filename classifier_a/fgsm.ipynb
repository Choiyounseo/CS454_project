# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

import matplotlib.pyplot as plt

# %%
epsilons = [0, .05, .1, .15, .2, .25, .3]
checkpoint = "checkpoint.pt"

batch_size = 1

# transform
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize(mean=(0.5,), std=(0.5,))])

test_dataset = datasets.MNIST(root='./mnist_data/',
                             train=False,
                             transform=transform,
                              download=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)
# Out:
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz
# 9920512it [00:00, 10303183.41it/s]
# Extracting ./mnist_data/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz
# 32768it [00:00, 137367.25it/s]
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnist_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 1654784it [00:00, 2343426.59it/s]
# 0it [00:00, ?it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 54323.27it/s]
# Extracting ./mnist_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist_data/MNIST/raw
# Processing...
# Done!

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.relu = nn.ReLU()
        self.batchnorm1 = nn.BatchNorm2d(num_features=64)

        self.conv1 = nn.Conv2d(in_channels=1, out_channels = 64, kernel_size=5, stride = 1, padding=2)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels = 64, kernel_size=5, stride = 2)
        self.dropout1 = nn.Dropout(0.25)
        self.FC1 = nn.Linear(64 *12 * 12, 128)
        self.dropout2 = nn.Dropout(0.5)
        self.FC2 = nn.Linear(128, 10)
        self.SM = nn.Softmax()
        
    def forward(self, x):
        in_size = x.size(0)
        
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = x.view(in_size, -1)
        x = self.dropout1(x)
        x = self.relu(self.FC1(x))
        x = self.dropout2(x)
        x = self.FC2(x)
        x = self.SM(x)

        return x

# %%
model = Net()
model.load_state_dict(torch.load(checkpoint))
model.eval()
# Out:
# Net(
#   (relu): ReLU()
#   (batchnorm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv1): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(64, 64, kernel_size=(5, 5), stride=(2, 2))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (FC1): Linear(in_features=9216, out_features=128, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (FC2): Linear(in_features=128, out_features=10, bias=True)
#   (SM): Softmax(dim=None)
# )

# %%
# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon * sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, -1, 1)
    # Return the perturbed image
    return perturbed_image

# %%
def test( model, test_loader, epsilon ):
    # Accuracy counter
    correct = 0
    adv_examples = [[] for i in range(10)]

    # Loop over all examples in test set
    for data, target in test_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        # print( target)

        # If the initial prediction is wrong, dont bother attacking, just move on
        if init_pred.item() != target.item():
            continue

        # Calculate the loss
        loss = F.nll_loss(output, target)

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        if final_pred.item() == target.item():
            correct += 1
            # Special case for saving 0 epsilon examples
            # if (epsilon == 0) and (len(adv_examples) < 5):
            #     adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
            #     adv_examples.append( (init_pred.item(), final_pred.item(), adv_ex) )
        else:
            # Save some adv examples for visualization later
            if len(adv_examples[target.item()]) < 100:
                adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                adv_examples[target.item()].append( (init_pred.item(), final_pred.item(), adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
accuracies = []
examples = []

# Run test for each epsilon
for eps in epsilons:
    acc, ex = test(model, test_loader, eps)
    accuracies.append(acc)
    examples.append(ex)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Epsilon: 0	Test Accuracy = 9605 / 10000 = 0.9605
# Epsilon: 0.05	Test Accuracy = 9241 / 10000 = 0.9241
# Epsilon: 0.1	Test Accuracy = 8479 / 10000 = 0.8479
# Epsilon: 0.15	Test Accuracy = 7097 / 10000 = 0.7097
# Epsilon: 0.2	Test Accuracy = 5288 / 10000 = 0.5288
# Epsilon: 0.25	Test Accuracy = 3704 / 10000 = 0.3704
# Epsilon: 0.3	Test Accuracy = 2585 / 10000 = 0.2585

# %%
# Plot several examples of adversarial samples at each epsilon
# cnt = 0
# plt.figure(figsize=(8,10))
# for i in range(len(epsilons)):
#     for j in range(len(examples[i])):
#         cnt += 1
#         plt.subplot(len(epsilons),len(examples[0]),cnt)
#         plt.xticks([], [])
#         plt.yticks([], [])
#         if j == 0:
#             plt.ylabel("Eps: {}".format(epsilons[i]), fontsize=14)
#         orig,adv,ex = examples[i][j]
#         plt.title("{} -> {}".format(orig, adv))
#         plt.imshow(ex, cmap="gray")
# plt.tight_layout()
# plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# A Tensor to a PIL image
def imsave(data, save=None): 
    # w, h = 512, 512
    I8 = (((data - data.min()) / (data.max() - data.min())) * 255.9).astype(np.uint8)
    pil_img = Image.fromarray(I8)
    pil_img.save(save)

# %%
# !mkdir fgsm_sample

# %%
for i in range(len(epsilons)):
    id = 0
    print(epsilons[i])
    for j in examples[i]:
        for orig, adv, ex in j:
            imsave(ex, save='./fgsm_sample/{}_{}_to_{}_{}.jpg'.format(epsilons[i], orig, adv, id))
            id += 1
# Out:
# 0
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3

# %%
# !zip -r fgsm_sample.zip fgsm_sample
# Out:
#   adding: fgsm_sample/ (stored 0%)
#   adding: fgsm_sample/0.2_0_to_5_81.jpg (stored 0%)
#   adding: fgsm_sample/0.2_6_to_8_646.jpg (stored 0%)
#   adding: fgsm_sample/0.1_9_to_4_887.jpg (stored 0%)
#   adding: fgsm_sample/0.3_1_to_8_168.jpg (stored 0%)
#   adding: fgsm_sample/0.2_5_to_4_556.jpg (stored 0%)
#   adding: fgsm_sample/0.3_3_to_8_366.jpg (stored 0%)
#   adding: fgsm_sample/0.05_9_to_7_326.jpg (stored 0%)
#   adding: fgsm_sample/0.1_0_to_5_1.jpg (stored 0%)
#   adding: fgsm_sample/0.1_7_to_3_596.jpg (stored 0%)
#   adding: fgsm_sample/0.1_6_to_5_572.jpg (stored 0%)
#   adding: fgsm_sample/0.2_4_to_8_448.jpg (stored 0%)
#   adding: fgsm_sample/0.15_5_to_3_583.jpg (stored 0%)
#   adding: fgsm_sample/0.3_1_to_8_115.jpg (stored 0%)
#   adding: fgsm_sample/0.25_4_to_9_445.jpg (stored 0%)
#   adding: fgsm_sample/0.05_9_to_4_363.jpg (stored 0%)
#   adding: fgsm_sample/0.3_5_to_8_522.jpg (stored 0%)
#   adding: fgsm_sample/0.3_6_to_8_655.jpg (stored 0%)
#   adding: fgsm_sample/0.2_1_to_8_115.jpg (stored 0%)
#   adding: fgsm_sample/0.1_9_to_4_834.jpg (stored 0%)
#   adding: fgsm_sample/0.3_7_to_0_756.jpg (stored 0%)
#   adding: fgsm_sample/0.3_2_to_1_232.jpg (stored 0%)
#   adding: fgsm_sample/0.3_4_to_9_424.jpg (stored 0%)
#   adding: fgsm_sample/0.15_7_to_2_727.jpg (stored 0%)
#   adding: fgsm_sample/0.05_5_to_3_175.jpg (stored 0%)
#   adding: fgsm_sample/0.3_2_to_3_208.jpg (stored 0%)
#   adding: fgsm_sample/0.1_3_to_5_261.jpg (stored 0%)
#   adding: fgsm_sample/0.25_7_to_3_739.jpg (stored 0%)
#   adding: fgsm_sample/0.1_4_to_9_342.jpg (stored 0%)
#   adding: fgsm_sample/0.05_3_to_9_97.jpg (stored 0%)
#   adding: fgsm_sample/0.25_7_to_9_761.jpg (stored 0%)
#   adding: fgsm_sample/0.3_0_to_5_0.jpg (stored 0%)
#   adding: fgsm_sample/0.2_3_to_5_306.jpg (stored 0%)
#   adding: fgsm_sample/0.15_6_to_4_682.jpg (stored 0%)
#   adding: fgsm_sample/0.3_9_to_2_928.jpg (stored 0%)
#   adding: fgsm_sample/0.25_4_to_9_455.jpg (stored 0%)
#   adding: fgsm_sample/0.25_2_to_3_215.jpg (stored 0%)
#   adding: fgsm_sample/0.15_9_to_4_910.jpg (stored 0%)
#   adding: fgsm_sample/0.15_2_to_6_225.jpg (stored 0%)
#   adding: fgsm_sample/0.25_4_to_9_495.jpg (stored 0%)
#   adding: fgsm_sample/0.05_2_to_4_64.jpg (stored 0%)
#   adding: fgsm_sample/0.15_4_to_9_414.jpg (stored 0%)
#   adding: fgsm_sample/0.05_5_to_8_172.jpg (stored 0%)
#   adding: fgsm_sample/0.3_7_to_2_736.jpg (stored 0%)
#   adding: fgsm_sample/0.15_4_to_5_406.jpg (stored 0%)
#   adding: fgsm_sample/0.1_6_to_5_528.jpg (stored 0%)
#   adding: fgsm_sample/0.05_4_to_9_105.jpg (stored 0%)
#   adding: fgsm_sample/0.2_6_to_5_641.jpg (stored 0%)
#   adding: fgsm_sample/0.2_0_to_6_23.jpg (stored 0%)
#   adding: fgsm_sample/0.3_8_to_6_813.jpg (stored 0%)
#   adding: fgsm_sample/0.1_9_to_4_808.jpg (stored 0%)
#   adding: fgsm_sample/0.2_8_to_5_826.jpg (stored 0%)
#   adding: fgsm_sample/0.1_4_to_9_347.jpg (stored 0%)
#   adding: fgsm_sample/0.1_1_to_8_106.jpg (stored 0%)
#   adding: fgsm_sample/0.2_8_to_3_892.jpg (stored 0%)
#   adding: fgsm_sample/0.25_2_to_3_263.jpg (stored 0%)
#   adding: fgsm_sample/0.2_1_to_8_154.jpg (stored 0%)
#   adding: fgsm_sample/0.2_2_to_1_277.jpg (stored 0%)
#   adding: fgsm_sample/0.25_0_to_2_15.jpg (stored 0%)
#   adding: fgsm_sample/0.25_1_to_7_191.jpg (stored 0%)
#   adding: fgsm_sample/0.3_1_to_3_136.jpg (stored 0%)
#   adding: fgsm_sample/0.1_9_to_5_860.jpg (stored 0%)
#   adding: fgsm_sample/0.2_4_to_9_455.jpg (stored 0%)
#   adding: fgsm_sample/0.3_8_to_3_822.jpg (stored 0%)
#   adding: fgsm_sample/0.2_0_to_6_91.jpg (stored 0%)
#   adding: fgsm_sample/0.25_6_to_8_684.jpg (stored 0%)
#   adding: fgsm_sample/0.05_9_to_3_341.jpg (stored 0%)
#   adding: fgsm_sample/0.2_9_to_7_963.jpg (stored 0%)
#   adding: fgsm_sample/0.25_6_to_4_626.jpg (stored 0%)
#   adding: fgsm_sample/0.2_0_to_5_57.jpg (stored 0%)
#   adding: fgsm_sample/0.15_7_to_9_748.jpg (stored 0%)
#   adding: fgsm_sample/0.3_8_to_4_882.jpg (stored 0%)
#   adding: fgsm_sample/0.1_2_to_8_190.jpg (stored 0%)
#   adding: fgsm_sample/0.3_0_to_2_1.jpg (stored 0%)
#   adding: fgsm_sample/0.15_4_to_9_395.jpg (stored 0%)
#   adding: fgsm_sample/0.15_9_to_4_983.jpg (stored 0%)
#   adding: fgsm_sample/0.1_3_to_9_263.jpg (stored 0%)
#   adding: fgsm_sample/0.25_3_to_5
jpg (stored 0%)
#   adding: fgsm_sample/0.3_2_to_3_221.jpg (stored 0%)
#   adding: fgsm_sample/0.1_9_to_4_847.jpg (stored 0%)
#   adding: fgsm_sample/0.1_6_to_4_556.jpg (stored 0%)
#   adding: fgsm_sample/0.25_9_to_7_949.jpg (stored 0%)
#   adding: fgsm_sample/0.25_4_to_6_435.jpg (stored 0%)
#   adding: fgsm_sample/0.2_5_to_8_564.jpg (stored 0%)
#   adding: fgsm_sample/0.3_8_to_3_894.jpg (stored 0%)
#   adding: fgsm_sample/0.2_3_to_5_303.jpg (stored 0%)
#   adding: fgsm_sample/0.25_2_to_3_219.jpg (stored 0%)
#   adding: fgsm_sample/0.15_5_to_9_553.jpg (stored 0%)
#   adding: fgsm_sample/0.25_8_to_5_856.jpg (stored 0%)
#   adding: fgsm_sample/0.2_6_to_5_647.jpg (stored 0%)
#   adding: fgsm_sample/0.1_6_to_5_551.jpg (stored 0%)
#   adding: fgsm_sample/0.2_5_to_8_520.jpg (stored 0%)
#   adding: fgsm_sample/0.1_8_to_3_768.jpg (stored 0%)
#   adding: fgsm_sample/0.15_2_to_3_199.jpg (stored 0%)
#   adding: fgsm_sample/0.15_7_to_9_722.jpg (stored 0%)
#   adding: fgsm_sample/0.15_7_to_2_761.jpg (stored 0%)
#   adding: fgsm_sample/0.25_0_to_8_46.jpg (stored 0%)
#   adding: fgsm_sample/0.2_1_to_8_173.jpg (stored 0%)
#   adding: fgsm_sample/0.2_5_to_7_510.jpg (stored 0%)
#   adding: fgsm_sample/0.15_0_to_5_61.jpg (stored 0%)
#   adding: fgsm_sample/0.2_9_to_4_989.jpg (stored 0%)
#   adding: fgsm_sample/0.2_3_to_5_368.jpg (stored 0%)
#   adding: fgsm_sample/0.15_1_to_8_120.jpg (stored 0%)
#   adding: fgsm_sample/0.25_2_to_6_236.jpg (stored 0%)
#   adding: fgsm_sample/0.3_7_to_3_720.jpg (stored 0%)
#   adding: fgsm_sample/0.2_3_to_5_389.jpg (stored 0%)
#   adding: fgsm_sample/0.1_9_to_4_851.jpg (stored 0%)
#   adding: fgsm_sample/0.1_8_to_5_700.jpg (stored 0%)
#   adding: fgsm_sample/0.15_3_to_5_313.jpg (stored 0%)
#   adding: fgsm_sample/0.15_7_to_3_693.jpg (stored 0%)
#   adding: fgsm_sample/0.25_9_to_4_943.jpg (stored 0%)
#   adding: fgsm_sample/0.1_8_to_6_702.jpg (stored 0%)
#   adding: fgsm_sample/0.2_4_to_9_493.jpg (stored 0%)
#   adding: fgsm_sample/0.25_2_to_3_209.jpg (stored 0%)
#   adding: fgsm_sample/0.15_3_to_2_333.jpg (stored 0%)
#   adding: fgsm_sample/0.1_7_to_9_616.jpg (stored 0%)
#   adding: fgsm_sample/0.2_1_to_8_165.jpg (stored 0%)
#   adding: fgsm_sample/0.1_2_to_8_209.jpg (stored 0%)
#   adding: fgsm_sample/0.2_9_to_7_969.jpg (stored 0%)
#   adding: fgsm_sample/0.25_6_to_8_674.jpg (stored 0%)
#   adding: fgsm_sample/0.25_8_to_5_849.jpg (stored 0%)
#   adding: fgsm_sample/0.3_5_to_4_589.jpg (stored 0%)
#   adding: fgsm_sample/0.25_5_to_3_554.jpg (stored 0%)
#   adding: fgsm_sample/0.2_1_to_7_193.jpg (stored 0%)
#   adding: fgsm_sample/0.15_5_to_9_584.jpg (stored 0%)
#   adding: fgsm_sample/0.15_2_to_4_248.jpg (stored 0%)
#   adding: fgsm_sample/0.3_1_to_3_124.jpg (stored 0%)
#   adding: fgsm_sample/0.15_6_to_8_626.jpg (stored 0%)
#   adding: fgsm_sample/0.2_5_to_8_585.jpg (stored 0%)
#   adding: fgsm_sample/0.05_5_to_7_179.jpg (stored 0%)
#   adding: fgsm_sample/0.15_2_to_3_244.jpg (stored 0%)
#   adding: fgsm_sample/0.25_1_to_3_137.jpg (stored 0%)
#   adding: fgsm_sample/0.25_0_to_6_75.jpg (stored 0%)
#   adding: fgsm_sample/0.15_5_to_8_557.jpg (stored 0%)
#   adding: fgsm_sample/0.3_2_to_1_201.jpg (stored 0%)
#   adding: fgsm_sample/0.2_7_to_2_753.jpg (stored 0%)
#   adding: fgsm_sample/0.1_2_to_7_173.jpg (stored 0%)
#   adding: fgsm_sample/0.2_7_to_9_729.jpg (stored 0%)
#   adding: fgsm_sample/0.25_9_to_4_900.jpg (stored 0%)
#   adding: fgsm_sample/0.2_9_to_4_909.jpg (stored 0%)
#   adding: fgsm_sample/0.1_8_to_3_703.jpg (stored 0%)
#   adding: fgsm_sample/0.25_1_to_8_145.jpg (stored 0%)
#   adding: fgsm_sample/0.05_8_to_3_267.jpg (stored 0%)
#   adding: fgsm_sample/0.3_9_to_8_907.jpg (stored 0%)
#   adding: fgsm_sample/0.25_2_to_8_264.jpg (stored 0%)
#   adding: fgsm_sample/0.05_7_to_5_230.jpg (stored 0%)
#   adding: fgsm_sample/0.1_2_to_3_183.jpg (stored 0%)
#   adding: fgsm_sample/0.3_4_to_8_476.jpg (stored 0%)
#   adding: fgsm_sample/0.15_2_to_8_213.jpg (stored 0%)
#   adding: fgsm_sample/0.1_6_to_4_548.jpg (stored 0%)
